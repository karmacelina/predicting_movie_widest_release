# %%
# !ls -l
# Out:
# total 26056
# -rw-r--r--  1 karma  staff     3342 Sep 29 23:07 Untitled.ipynb
# -rw-r--r--  1 karma  staff       72 Oct  2 13:20 Untitled1.ipynb
# -rw-r--r--  1 karma  staff    28634 Sep 30 16:17 more_scraping-Copy1.ipynb
# -rw-r--r--  1 karma  staff  1449366 Oct  2 01:07 more_scraping_this_is_working.ipynb
# -rw-r--r--  1 karma  staff  2178034 Oct  1 22:55 movies_1.pkl
# -rw-r--r--  1 karma  staff  2180537 Oct  1 23:49 movies_1_v2.pkl
# -rw-r--r--  1 karma  staff   835136 Oct  2 00:52 movies_2.pkl
# -rw-r--r--  1 karma  staff   323027 Oct  1 22:11 scraping_luther_1.ipynb
# -rw-r--r--  1 karma  staff  6254623 Sep 29 18:11 scraping_miscellaneous.ipynb
# -rw-r--r--  1 karma  staff    73713 Sep 30 22:28 scraping_trick.ipynb

# %%
import pandas as pd 

df1 = pd.read_pickle('movies_1_v2.pkl')

# %%
df2 = pd.read_pickle('movies_2.pkl')

# %%
df = df1.append(df2, ignore_index=True)

# %%
df.shape
# Out:
# (16451, 14)

# %%
import copy

# %%
df3 = df.copy()

# %%
del df3['actors']

# %%
df.columns
# Out:
# Index(['movie', 'genre', 'release date', 'distributor', 'runtime', 'rating',
#        'budget', 'domestic gross', 'actors', '1st weekend gross',
#        'widest release', 'producers', 'directors', 'title'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['movie', 'genre', 'release date', 'distributor', 'runtime', 'rating',
#        'budget', 'domestic gross', '1st weekend gross', 'widest release',
#        'producers', 'directors', 'title'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.columns
# Out:
# Index(['movie', 'genre', 'release date', 'distributor', 'runtime', 'rating',
#        'budget', 'domestic gross', 'actors', '1st weekend gross',
#        'widest release', 'producers', 'directors', 'title'],
#       dtype='object')

# %%
df['widest release'].hist(bins = 100)

# %%
plt.scatter(df['runtime'], df['widest release'])

# %%
plt.scatter(df['widest release'], df['budget'])

# %%
plt.scatter(df['budget'], df['domestic gross'])

# %%
plt.scatter(df['widest release'], df['domestic gross'])

# %%
df['runtime'].hist(bins = 100)

# %%
df2['runtime'].hist(bins = 100)

# %%
plt.scatter(df['runtime'], df['domestic gross'])

# %%
df['domestic gross'].hist(bins = 100)

# %%
df2['domestic gross'].hist(bins = 100)

# %%
actors_2 = df['actors'].fillna('o')

# %%
len(actors_2)
# Out:
# 16451

# %%
actors_list = [] 
for i in range(len(actors_2)):
    for actor in actors_2[i]:
        actors_list.append(actor)

# %%
from collections import Counter

# %%
actors_dict = Counter(actors_list)
